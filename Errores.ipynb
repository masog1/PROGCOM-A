# %% [markdown]
# <a href="https://colab.research.google.com/github/masog1/PROGCOM-A/blob/main/Errores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. SyntaxError → error de sintaxis
print("Hola"

# 2. IndentationError → error de identación
def funcion():
print("mal identado")

# 3. NameError → variable no definida
print(variable_que_no_existe)

# 4. TypeError → operación con tipos incompatibles
print("texto" + 5)

# 5. ValueError → valor no válido
int("hola")

# 6. ZeroDivisionError → división entre cero
print(10 / 0)

# 7. IndexError → índice fuera de rango
lista = [1, 2, 3]
print(lista[5])

# 8. KeyError → clave inexistente en diccionario
dic = {"a": 1}
print(dic["b"])

# 9. AttributeError → atributo que no existe
numero = 5
numero.append(3)

# 10. ModuleNotFoundError → módulo inexistente
import modulo_falso

# 11. ImportError → fallo al importar
from math import cosa_que_no_existe

# 12. FileNotFoundError → archivo no existe
open("archivo_inexistente.txt")

# 13. PermissionError → sin permisos para abrir archivo
open("/etc/shadow", "r")

# 14. OverflowError → número demasiado grande
import math
print(math.exp(1000))

# 15. RecursionError → recursión infinita
def rec():
    return rec()
rec()

# 16. MemoryError → uso excesivo de memoria
x = [1] * (10**10)

# 17. FloatingPointError → error en cálculo de flotantes
import sys
sys.float_info.max * 2

# 18. StopIteration → al usar iteradores manuales
it = iter([1])
next(it)
next(it)

# 19. AssertionError → afirmación falsa
assert 2 + 2 == 5, "Las mates fallaron"

# 20. RuntimeError → error genérico de ejecución
import asyncio
loop = asyncio.get_event_loop()
loop.run_until_complete(loop.shutdown_asyncgens())
raise RuntimeError("Fallo en tiempo de ejecución")

# 21. UnicodeEncodeError → error al codificar
"á".encode("ascii")

# 22. UnicodeDecodeError → error al decodificar
b'\xff'.decode("utf-8")

# 23. UnicodeTranslateError → traducción inválida
"hola".translate({111: None})

# 24. EOFError → final de input inesperado
input()

# 25. KeyboardInterrupt → interrupción del usuario
raise KeyboardInterrupt

# 26. SystemExit → salida del sistema
import sys
sys.exit()

# 27. EnvironmentError → error del entorno
raise EnvironmentError("Fallo de entorno")

# 28. IsADirectoryError → intentar abrir un directorio
open(".")

# 29. NotADirectoryError → ruta no es directorio
import os
os.listdir("archivo.txt")

# 30. BlockingIOError → operación bloqueada
raise BlockingIOError("Ejemplo artificial")

# 31. ChildProcessError → error con proceso hijo
raise ChildProcessError("No hay proceso hijo")

# 32. ConnectionError → error de conexión
raise ConnectionError("Conexión fallida")

# 33. BrokenPipeError → tubería rota
raise BrokenPipeError("Pipe roto")

# 34. ConnectionAbortedError → conexión abortada
raise ConnectionAbortedError("Abortada")

# 35. ConnectionRefusedError → conexión rechazada
raise ConnectionRefusedError("Rechazada")

# 36. ConnectionResetError → conexión reseteada
raise ConnectionResetError("Reseteada")

# 37. TimeoutError → tiempo de espera agotado
raise TimeoutError("Se acabó el tiempo")

# 38. ProcessLookupError → proceso no encontrado
raise ProcessLookupError("No existe proceso")

# 39. OSError → error general de SO
raise OSError("Error del sistema operativo")

# 40. ArithmeticError → error aritmético base
raise ArithmeticError("Error de cálculo")

# 41. LookupError → error de búsqueda
raise LookupError("Error de búsqueda general")

# 42. BufferError → error de buffer
raise BufferError("Error en el buffer")

# 43. UnboundLocalError → variable local usada antes de asignarse
def f():
    print(x)
    x = 10
f()

# 44. BrokenPipeError → error en pipe
raise BrokenPipeError("Pipe roto de nuevo")

# 45. GeneratorExit → cierre de generador
def gen():
    yield 1
g = gen()
g.close()
next(g)

# 46. StopAsyncIteration → error en async iterator
async def aiter():
    raise StopAsyncIteration
import asyncio
asyncio.run(aiter())

# 47. ImportWarning → advertencia de importación
import warnings
warnings.warn("Problema de importación", ImportWarning)

# 48. DeprecationWarning → advertencia de deprecación
warnings.warn("Esto está obsoleto", DeprecationWarning)

# 49. FutureWarning → advertencia de futuro
warnings.warn("Cambio en el futuro", FutureWarning)

# 50. SyntaxWarning → advertencia de sintaxis
warnings.warn("Sintaxis dudosa", SyntaxWarning)

# 51. RuntimeWarning → advertencia en ejecución
warnings.warn("Algo salió raro", RuntimeWarning)

# 52. UserWarning → advertencia del usuario
warnings.warn("Advertencia definida por usuario")

# 53. UnicodeWarning → advertencia unicode
warnings.warn("Problema unicode", UnicodeWarning)

# 54. BytesWarning → advertencia en bytes
warnings.warn("Problema con bytes", BytesWarning)

# 55. ResourceWarning → advertencia de recursos
warnings.warn("Recurso no cerrado", ResourceWarning)

# 56. ArithmeticError por sqrt negativo
import math
math.sqrt(-1)

# 57. ValueError en rango inválido
list(range(0, -5))

# 58. IndexError string vacío
"abc"[10]

# 59. NameError en función no definida
funcion_inexistente()

# 60. TypeError en len
len(42)

# 61. OverflowError por factorial gigante
math.factorial(10**6)

# 62. ZeroDivisionError en flotantes
1.0/0.0

# 63. RecursionError profundo
def rec2(): return rec2()
rec2()

# 64. SyntaxError con palabra mal escrita
evall("2+2")

# 65. ImportError módulo no válido
import jsons

# 66. ModuleNotFoundError librería falsa
import lalib

# 67. ValueError al convertir
float("tres")

# 68. KeyError en dict
d = {}
d["clave"]

# 69. FileNotFoundError abrir inexistente
open("nada.txt")

# 70. PermissionError crear en root
open("/root/archivo.txt", "w")

# 71. OSError ruta inválida
open("\0")

# 72. AssertionError falso
assert False

# 73. RuntimeError ejemplo
raise RuntimeError("Error runtime")

# 74. StopIteration manual
raise StopIteration

# 75. StopAsyncIteration manual
raise StopAsyncIteration

# 76. SystemExit salida
raise SystemExit

# 77. KeyboardInterrupt
raise KeyboardInterrupt

# 78. EOFError entrada
raise EOFError

# 79. UnicodeEncodeError ascii
"ñ".encode("ascii")

# 80. UnicodeDecodeError
b"\xff".decode("utf-8")

# 81. UnicodeTranslateError
"texto".translate({116: None})

# 82. BufferError
raise BufferError

# 83. LookupError
raise LookupError

# 84. ArithmeticError base
raise ArithmeticError

# 85. FloatingPointError manual
raise FloatingPointError

# 86. MemoryError manual
raise MemoryError

# 87. ReferenceError (usando weakref mal)
import weakref
class A: pass
a = A()
r = weakref.ref(a)
del a
print(r().algo)

# 88. OverflowError exp
math.exp(1000)

# 89. ValueError log negativo
math.log(-1)

# 90. TypeError suma str+int
"10" + 10

# 91. AttributeError lista sort con args raros
[].sort("hola")

# 92. IndexError pop vacío
[].pop()

# 93. KeyError pop inexistente
{}.pop("hola")

# 94. FileNotFoundError remove
import os
os.remove("archivo_inexistente.txt")

# 95. ProcessLookupError
raise ProcessLookupError

# 96. TimeoutError
raise TimeoutError

# 97. ConnectionError
raise ConnectionError

# 98. ConnectionAbortedError
raise ConnectionAbortedError

# 99. ConnectionRefusedError
raise ConnectionRefusedError

# 100. ConnectionResetError
raise ConnectionResetError

# 101. ChildProcessError
raise ChildProcessError

# 102. BlockingIOError
raise BlockingIOError

# 103. IsADirectoryError
raise IsADirectoryError

# 104. NotADirectoryError
raise NotADirectoryError

# 105. BrokenPipeError
raise BrokenPipeError

# 106. FileExistsError
import os
os.mkdir("carpeta")
os.mkdir("carpeta")

# 107. ArithmeticError división
raise ArithmeticError("Error aritmético")

# 108. AssertionError manual
raise AssertionError("Fallo de prueba")

# 109. UnboundLocalError
def prueba():
    print(x)
    x=1
prueba()

# 110. RuntimeError en generador
def gen2():
    yield 1
g2 = gen2()
g2.throw(RuntimeError("Forzado"))
