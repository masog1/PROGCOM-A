# %% [markdown]
# <a href="https://colab.research.google.com/github/masog1/PROGCOM-A/blob/main/CQ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image (1).png](data:image/png;base64,...)
